# %% [markdown]
# ![28.png](data:image/png;base64,...)

# %% [markdown]
# ## Ubuntu 설치

# %% [markdown]
# **1. Microsoft Store에서 Ubuntu 프로그램 설치**<br>
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# **2. 재부팅**

# %% [markdown]
# **3. 계정 생성**<br>
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# **4. 설치 완료**<br>
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# ## Visual Studio 설치

# %% [markdown]
# **1. [Visual Studio Code 다운로드 사이트](https://code.visualstudio.com/download) 접속**

# %% [markdown]
# **2. Windows 버전으로 실행파일(.exe) 다운 후 설치** <br>
# * Linux 버전으로 설치 시 ubuntu 내에서 vscode 실행이 되지 않는 문제 발생 <br><br>
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# **3. 설치 완료**<br>
# ![6.png](data:image/png;base64,...)

# %% [markdown]
# ## SSH 키 생성

# %% [markdown]
# **1. SSH 키 확인**<br>
# ls -al ~/.ssh<br>
# ![7.png](data:image/png;base64,...)

# %% [markdown]
# **2. SSH 키 생성**<br>
# ssh-keygen -t rsa -C "echoz4640@bme.gachon.ac.kr"<br>
# ![8.png](data:image/png;base64,...)

# %% [markdown]
# - 결과<br>
# ![9.png](data:image/png;base64,...)

# %% [markdown]
# **3. public key 내용 복사**<br>
# cat ~/.ssh/id_rsa.pub<br>
# ![10.png](data:image/png;base64,...)

# %% [markdown]
# **4. GitHub 등록**<br>
# ![11.png](data:image/png;base64,...)

# %% [markdown]
# ## Miniconda 설치

# %% [markdown]
# **1. 인스톨러 설치**<br>
# ~$ wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh<br>
# ![16.png](data:image/png;base64,...)

# %% [markdown]
# **2.Miniconda 설치**<br>
# ~$ bash Miniconda3-latest-Linux-x86_64.sh<br>
# ![17.png](data:image/png;base64,...)

# %% [markdown]
# **3. Extension 설치**<br>
# - GitHub Repositories: GitHub repository에 접근하기 위해 설치
# - Jupyter: 코드 실행 시, kernel로 사용하기 위해 설치<br>
# ![31.png](data:image/png;base64,...)

# %% [markdown]
# ## Visual Studio Code와 Ubuntu 연동

# %% [markdown]
# ~$ code .<br>
# ![12.png](data:image/png;base64,...)

# %% [markdown]
# ## 가상환경 설정

# %% [markdown]
# **1. 가상환경 활성화**<br>
# ~$ source ~/.bashrc<br>
# ![13.png](data:image/png;base64,...)

# %% [markdown]
# **2. 가상환경 생성**<br>
# ~$ conda create -n LINC_ML python=3.9<br>
# - 가상환경 이름: LINC_ML<br>
# - python version: 3.9<br>
# ![18.png](data:image/png;base64,...)

# %% [markdown]
# **3. 가상환경 활성화**<br>
# ~$ conda activate LINC_ML<br>
# ![19.png](data:image/png;base64,...)

# %% [markdown]
# ## 기본 라이브러리 설치

# %% [markdown]
# - pandas<br>
# ~$ conda install pandas<br>
# ![20.png](data:image/png;base64,...)

# %% [markdown]
# - matplotlib<br>
# ~$ conda install matplotlib<br>
# ![21.png](data:image/png;base64,...)

# %% [markdown]
# - seaborn<br>
# ~$ conda install seaborn<br>
# ![22.png](data:image/png;base64,...)

# %% [markdown]
# - numpy: 기본으로 설치가 되어 있었음<br>
# ~$ conda install numpy<br>
# ![29.png](data:image/png;base64,...)

# %% [markdown]
# ## 점검

# %% [markdown]
# - Ubuntu 환경에서 Visual Studio Code 실행<br>
# ![27.png](data:image/png;base64,...)

# %% [markdown]
# - Visual Studio Code에 GitHub 연동<br>
# ![24.png](data:image/png;base64,...)

# %% [markdown]
#    - Repository 접근<br>
# ![30.png](data:image/png;base64,...)
